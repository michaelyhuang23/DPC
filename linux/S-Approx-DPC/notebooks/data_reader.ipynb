# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import re

# %%
root = '../results'
names = ['sensor5']

# %%
dict_data = []
data_names = os.listdir(root)
for name in names:
    for data_name in data_names:
        if not name in data_name: continue
        run = int(data_name[-1:])
        print(f'reading {data_name}')
        for item in os.listdir(os.path.join(root, data_name)):
            if not item.endswith('.txt'): continue
            with open(os.path.join(root, data_name, item)) as f:
                string = ''.join(f.readlines()[1:])
                lines = re.split('time: |\[', string)
            nums = [float(word) for word in lines if word[0].isdigit()]
            print(item)
            file_name = item.split('.txt')[0]
            alg_name = file_name.split('_')[0]
            r = float(file_name.split('_')[1])
            n = 20
            thread = int(file_name.split('_')[2])
            dict_data.append({'name':alg_name, 'r':r, 'n':n, 'thread':thread, 'run':run, 'part':'density computation', 'time':nums[0]+nums[1]})
            dict_data.append({'name':alg_name, 'r':r, 'n':n, 'thread':thread, 'run':run, 'part':'dependent point finding', 'time':nums[2]})
            dict_data.append({'name':alg_name, 'r':r, 'n':n, 'thread':thread, 'run':run, 'part':'single linkage clustering', 'time':nums[3]})
df = pd.DataFrame.from_records(dict_data)
# Out:
# reading sensor51
# orig_0.2_4.txt
# orig_0.2_1.txt
# orig_0.2_2.txt
# orig_0.2_30.txt
# orig_0.2_16.txt
# orig_0.2_60.txt
# orig_0.2_8.txt
# reading sensor52
# orig_0.2_4.txt
# orig_0.2_1.txt
# orig_0.2_2.txt
# orig_0.2_30.txt
# orig_0.2_16.txt
# orig_0.2_60.txt
# orig_0.2_8.txt
# reading sensor53
# orig_0.2_4.txt
# orig_0.2_1.txt
# orig_0.2_2.txt
# orig_0.2_30.txt
# orig_0.2_16.txt
# orig_0.2_60.txt
# orig_0.2_8.txt

# %%
df
# Out:
#     name    r   n  thread  run                       part         time
# 0   orig  0.2  20       4    1        density computation  1992.287250
# 1   orig  0.2  20       4    1    dependent point finding  1376.820000
# 2   orig  0.2  20       4    1  single linkage clustering     0.284375
# 3   orig  0.2  20       1    1        density computation  6473.952440
# 4   orig  0.2  20       1    1    dependent point finding  2069.040000
# ..   ...  ...  ..     ...  ...                        ...          ...
# 58  orig  0.2  20      60    3    dependent point finding   114.432000
# 59  orig  0.2  20      60    3  single linkage clustering     0.155049
# 60  orig  0.2  20       8    3        density computation  1025.926860
# 61  orig  0.2  20       8    3    dependent point finding   635.614000
# 62  orig  0.2  20       8    3  single linkage clustering     0.255593
#
# [63 rows x 7 columns]

# %%
def drop_and_sum(df, column):
    if column not in df.columns: return df
    df = df.drop([column], axis=1)
    columns = list(df.columns)
    columns.remove('time')
    df = df.groupby(columns).sum()
    return df.reset_index()

# %%
df = drop_and_sum(df, 'run')
df['time']/=3

# %%
df.head()
# Out:
#    name    r   n  thread                       part         time
# 0  orig  0.2  20       1        density computation  6447.398333
# 1  orig  0.2  20       1    dependent point finding  2126.046667
# 2  orig  0.2  20       1  single linkage clustering     0.945320
# 3  orig  0.2  20       2        density computation  3284.627337
# 4  orig  0.2  20       2    dependent point finding  2185.106667

# %%
df.to_csv('../data_sensor5.csv')
